# %% [markdown]
# # Steel Plate Defect Prediction
# <img src="https://www.researchgate.net/publication/354760527/figure/fig1/AS:11431281388040366@1745159899699/Surface-defects-of-steel-plate.tif" width=600>
#
#
# This project is a Kaggle competition where the main goal is to develop a machine learning model that predicts potential manufacturing defects using feature data from steel plates. This is a **multi-label classification** problem.
#
# The dataset consists of numerous columns containing various geometric and physical properties of the plates. In this project, the **target columns** we will try to predict with our model represent 7 different types of faults:
#
# * `Pastry`
# * `Z_Scratch`
# * `K_Scatch`
# * `Stains`
# * `Dirtiness`
# * `Bumps`
# * `Other_Faults`
#
# The model's performance will be evaluated by the average of the **ROC AUC** scores calculated for each fault type.
#
# The dataset was taken from Kaggle:
#
# [Steel Plate Defect Prediction](https://www.kaggle.com/competitions/playground-series-s4e3/overview)

# %% [markdown]
# ## Data Read

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
train.head()
# Out:
#    id  X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0   0        584        590     909972     909977            16            8
# 1   1        808        816     728350     728372           433           20
# 2   2         39        192    2212076    2212144         11388          705
# 3   3        781        789    3353146    3353173           210           16
# 4   4       1540       1560     618457     618502           521           72
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0            5               2274                    113
# 1           54              44478                     70
# 2          420            1311391                     29
# 3           29               3202                    114
# 4           67              48231                     82
#
#    Maximum_of_Luminosity  Length_of_Conveyer  TypeOfSteel_A300  \
# 0                    140                1358                 0
# ...

# %%
train.columns
# Out:
# Index(['id', 'X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum',
#        'Pixels_Areas', 'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity',
#        'Minimum_of_Luminosity', 'Maximum_of_Luminosity', 'Length_of_Conveyer',
#        'TypeOfSteel_A300', 'TypeOfSteel_A400', 'Steel_Plate_Thickness',
#        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
#        'Edges_X_Index', 'Edges_Y_Index', 'Outside_Global_Index', 'LogOfAreas',
#        'Log_X_Index', 'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index',
#        'SigmoidOfAreas', 'Pastry', 'Z_Scratch', 'K_Scatch', 'Stains',
#        'Dirtiness', 'Bumps', 'Other_Faults'],
#       dtype='object')

# %%
train.shape
# Out:
# (19219, 35)

# %%
train.head().T
# Out:
#                                  0            1             2             3  \
# id                          0.0000       1.0000  2.000000e+00  3.000000e+00
# X_Minimum                 584.0000     808.0000  3.900000e+01  7.810000e+02
# X_Maximum                 590.0000     816.0000  1.920000e+02  7.890000e+02
# Y_Minimum              909972.0000  728350.0000  2.212076e+06  3.353146e+06
# Y_Maximum              909977.0000  728372.0000  2.212144e+06  3.353173e+06
# Pixels_Areas               16.0000     433.0000  1.138800e+04  2.100000e+02
# X_Perimeter                 8.0000      20.0000  7.050000e+02  1.600000e+01
# Y_Perimeter                 5.0000      54.0000  4.200000e+02  2.900000e+01
# Sum_of_Luminosity        2274.0000   44478.0000  1.311391e+06  3.202000e+03
# Minimum_of_Luminosity     113.0000      70.0000  2.900000e+01  1.140000e+02
# Maximum_of_Luminosity     140.0000     111.0000  1.410000e+02  1.340000e+02
# ...

# %%
train.isnull().sum()
# Out:
# id                       0
# X_Minimum                0
# X_Maximum                0
# Y_Minimum                0
# Y_Maximum                0
# Pixels_Areas             0
# X_Perimeter              0
# Y_Perimeter              0
# Sum_of_Luminosity        0
# Minimum_of_Luminosity    0
# Maximum_of_Luminosity    0
# Length_of_Conveyer       0
# TypeOfSteel_A300         0
# TypeOfSteel_A400         0
# Steel_Plate_Thickness    0
# Edges_Index              0
# Empty_Index              0
# Square_Index             0
# Outside_X_Index          0
# Edges_X_Index            0
# Edges_Y_Index            0
# Outside_Global_Index     0
# LogOfAreas               0
# Log_X_Index              0
# Log_Y_Index              0
# Orientation_Index        0
# Luminosity_Index         0
# SigmoidOfAreas           0
# Pastry                   0
# Z_Scratch                0
# K_Scatch                 0
# Stains                   0
# Dirtiness                0
# Bumps                    0
# ...

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19219 entries, 0 to 19218
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     19219 non-null  int64
#  1   X_Minimum              19219 non-null  int64
#  2   X_Maximum              19219 non-null  int64
#  3   Y_Minimum              19219 non-null  int64
#  4   Y_Maximum              19219 non-null  int64
#  5   Pixels_Areas           19219 non-null  int64
#  6   X_Perimeter            19219 non-null  int64
#  7   Y_Perimeter            19219 non-null  int64
#  8   Sum_of_Luminosity      19219 non-null  int64
#  9   Minimum_of_Luminosity  19219 non-null  int64
#  10  Maximum_of_Luminosity  19219 non-null  int64
#  11  Length_of_Conveyer     19219 non-null  int64
#  12  TypeOfSteel_A300       19219 non-null  int64
#  13  TypeOfSteel_A400       19219 non-null  int64
#  14  Steel_Plate_Thickness  19219 non-null  int64
# ...

# %%
train.drop('id', axis=1).describe()
# Out:
#           X_Minimum     X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas  \
# count  19219.000000  19219.000000  1.921900e+04  1.921900e+04   19219.000000
# mean     709.854675    753.857641  1.849756e+06  1.846605e+06    1683.987616
# std      531.544189    499.836603  1.903554e+06  1.896295e+06    3730.319865
# min        0.000000      4.000000  6.712000e+03  6.724000e+03       6.000000
# 25%       49.000000    214.000000  6.574680e+05  6.575020e+05      89.000000
# 50%      777.000000    796.000000  1.398169e+06  1.398179e+06     168.000000
# 75%     1152.000000   1165.000000  2.368032e+06  2.362511e+06     653.000000
# max     1705.000000   1713.000000  1.298766e+07  1.298769e+07  152655.000000
#
#         X_Perimeter   Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count  19219.000000  19219.000000       1.921900e+04           19219.000000
# mean      95.654665     64.124096       1.918467e+05              84.808419
# ...

# %%
target=['Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fault_counts = train[target].sum().sort_values(ascending=False)

# %%
print(fault_counts)
# Out:
# Other_Faults    6558
# Bumps           4763
# K_Scatch        3432
# Pastry          1466
# Z_Scratch       1150
# Stains           568
# Dirtiness        485
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=fault_counts.index, y=fault_counts.values, palette='viridis')
plt.title('Distribution of Error Types in Training Data', fontsize=16)
plt.xlabel('Type of Error', fontsize=12)
plt.ylabel('Total number', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
colors = sns.color_palette('pastel')

plt.figure(figsize=(10, 10))
plt.pie(fault_counts, 
        labels=fault_counts.index, 
        colors=colors,
        autopct='%1.1f%%',   
        startangle=120)      

plt.title('Distribution of Fault Types (Pie Chart)', fontsize=16, fontweight='bold')
plt.axis('equal') 

plt.show()

# %%
features = [col for col in train.columns if col not in ['id'] + target]

plt.figure(figsize=(25, 15))

for index, col in enumerate(features, start=1):
    plt.subplot(4, 7, index)
    plt.hist(train[col], bins=30, density=True, color='c')
    plt.title(col, fontsize=10)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,14), dpi=150)
sns.heatmap(train.select_dtypes(include='number').corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preprocessing

# %%
target = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

def combine_target_variables(row):
    defect = None
    for col in target:
        if row[col] == 1:
            defect = col
            break
    if defect:
        return defect
    else:
        return 'No Defect'

# %%
train['Target'] = train.apply(combine_target_variables, axis=1)

# %%
train.head()
# Out:
#    id  X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0   0        584        590     909972     909977            16            8
# 1   1        808        816     728350     728372           433           20
# 2   2         39        192    2212076    2212144         11388          705
# 3   3        781        789    3353146    3353173           210           16
# 4   4       1540       1560     618457     618502           521           72
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0            5               2274                    113
# 1           54              44478                     70
# 2          420            1311391                     29
# 3           29               3202                    114
# 4           67              48231                     82
#
#    Maximum_of_Luminosity  Length_of_Conveyer  TypeOfSteel_A300  \
# 0                    140                1358                 0
# ...

# %%
train.drop(columns=['Target'], inplace=True)

# %%
target_col = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

# %% [markdown]
# ## Modelling

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

# %%
x = train.drop(target_col, axis=1)
y = train[target_col]

# %%
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
xgboost_model = xgb.XGBClassifier(
    objective="binary:logistic",
    eval_metric="auc",
    #max_depth=12,  
    learning_rate=0.005,
    subsample=0.85,
    colsample_bytree=0.85,
    alpha=0.001,
    reg_lambda=0.001,  
    gamma=0.1,
    min_child_weight=5,
    n_estimators=1500,
    random_state=42
)

# %%
xgboost_model.fit(x_train, y_train)
# Out:
# XGBClassifier(alpha=0.001, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.85, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=0.1, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.005, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=1500,
#               n_jobs=None, ...)

# %%
tahmin = xgboost_model.predict_proba(x_test)

# %%
auc_scores = []

# %%
auc_score = roc_auc_score(y_test, tahmin)

# %%
auc_scores.append(auc_score)

# %%
mean_auc_score = np.mean(auc_scores)

# %%
print("Mean AUC Score (XGBoost):", mean_auc_score)
# Out:
# Mean AUC Score (XGBoost): 0.8873188694146253

# %% [markdown]
# ## Conclusion
#
# In this project, a **multi-label classification** problem was addressed, aiming to predict 7 different types of steel plate defects.
#
# The **XGBoost** model trained for this task achieved a high **Mean AUC Score of 0.8873** on the test data. This result demonstrates that the model is highly successful at distinguishing between different fault types and offers an effective solution for predicting steel plate defects.
